# %% [markdown]
# $$f(n) = 3n^2 - n + 4$$
# $$g(n) = n \log n + 5$$
# $$f(n) + g(n) = O(n^2)$$
#
# $$|f(n) + g(n)| \le C \cdot n^2$$
#
# $$h(n) = f(n) + g(n) = (3n^2 - n + 4) + (n \log n + 5) = 3n^2 + n \log n - n + 9$$
#
#
#
#
#
# 1) $3n^2 \le 3n^2$
#
# 2) $n \log n < n \cdot n = n^2$
#
# 3) $-n \le 0$
#
# 4) $9 \le 9n^2$
#
#
# $$|f(n) + g(n)| \le 3n^2 + n^2 + 9n^2$$
# $$|f(n) + g(n)| \le 13n^2$$
#
# $$ C = 13, n_0 = 1$$
# $$\implies f(n) + g(n) = O(n^2)$$
