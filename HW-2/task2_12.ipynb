# %%
# %run task2_10.ipynb
# %run task2_11.ipynb

def h(n):
    return f(n) + g(n) # O(n) + O(n^2) = O(n^2)

# T(n) = O(n^2)
# The result is n(n+1) + n(n+1)(n+2)//6

def improved_h(n):
    return n * (n + 1) + n * (n + 1) * (n + 2) // 6
