# %%
# %run task2_10.ipynb

def g(n):
    sum = 0                   # O(1)
    for i in range(1, n + 1): # O(n)
        sum = sum + i + f(i)  # O(i)
        return sum            # O(1)

# When i=n: f(i) = f(n), thus
# T(n) = O(n) * O(n) = O(n^2)
# The result is n(n+1)//2 + n(n+1)(n+2)//6

def improved_g(n):
    return  n * (n + 1) // 2 + n * (n + 1) * (n + 2) // 6 # O(1)
